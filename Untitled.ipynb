# %%
import pandas as pd

# %%
import numpy as np

# %%
dict= {
    "Name" : ['Hardik', 'Janenie', 'Manas','Aayush'],
    "Places" : ['Canada', 'Canada', 'Russia', 'USA'],
    "Packages" : ['1B','5B','1M','0.5M']
}

# %%
f=pd.DataFrame(dict)

# %%
f
# Out:
#       name  places Packages
# 0   hardik  Canada       1B
# 1  Janenie  Canada       5B
# 2    Manas  Russia       1M
# 3   Aayush     USA     0.5M

# %%
f.to_csv("hardik.csv")

# %%
f.to_csv("hardik_index_false.csv", index = False)

# %%
f.head(2)
# Out:
#       Name  Places Packages
# 0   Hardik  Canada       1B
# 1  Janenie  Canada       5B

# %%
f.tail(1)
# Out:
#      Name Places Packages
# 3  Aayush    USA     0.5M

# %%
f.describe()
# Out:
#           Name  Places Packages
# count        4       4        4
# unique       4       3        4
# top     Hardik  Canada       1B
# freq         1       2        1

# %%
hardik = pd.read_csv('hardik.csv')

# %%
hardik
# Out:
#     Sl No  Batch No           Reg.No              NAME OF THE STUDENT  \
# 0       1  SOC - B1  RA2011027010007                  SHIVAM PAHARIYA
# 1       2  SOC - B1  RA2011003011090                   ADITYA SINGHAL
# 2       3  SOC - B1  RA2011003010330                     AYUSH BHARTI
# 3       4  SOC - B1  RA2011003010307                PRIYANSHU GROVER
# 4       5  SOC - B1  RA2011030010224                     SOORAJ TOMAR
# 5       6  SOC - B1  RA2011003010129                      KHUSHI SURI
# 6       7  SOC - B1  RA2011003010539                       ABINAYA S
# 7       8  SOC - B1  RA2011027010099                   SHUBHAM PRABHU
# 8       9  SOC - B1  RA2011003010077                SHASHWATH SUVARNA
# 9      10  SOC - B1  RA2011027010068           DHRUV JITENDRA LIMBANI
# 10     11  SOC - B1  RA2011047010095                 ALURU LEELA RANI
# 11     12  SOC - B1  RA2011030010106           T SHRESHT PRATAP SINGH
# 12     13  SOC - B1  RA2011003011080                SHIVAGURUPRIYAA G
# 13     14  SOC - B1  RA2011003010119                    TANMAY SHUKLA
# 14     15  SOC - B1  RA2011026010109                VISHVESH BHARDWAJ
# 15     16  SOC - B1  RA2011026010158                       ARNAV JAIN
# 16     17  SOC - B1  RA2011028010032                     ARITRA DUTTA
# 17     18  SOC - B1  RA2011030010004                    MEDHAVI MEHTA
# 18     19  SOC - B1  RA2011028010013                     KOLLI VASAVI
# 19     20  SOC - B1  RA2011050010001         MANEPALLI NARAYANA VAMSI
# 20     21  SOC - B1  RA2011026010300                A.BHAVANI SHANKAR
# 21     22  SOC - B1  RA2011026010306  MADDU SAI NAGA VEERA BHADRA RAO
# 22     23  SOC - B1  RA2011003010267             BHAGYASRI DOMMARAJU
# 23     24  SOC - B1  RA2011028010145                  ARYAN RAJ SINGH
# 24     25  SOC - B1  RA2011031010101                 AMAN KUMAR SINGH
# 25     26  SOC - B1  RA2011033010121                       S P JAGRIT
# 26     27  SOC - B1  RA2011031010068                     NYASA GUPTA
# 27     28  SOC - B1  RA2011030010099                  PRATYUSHA ROUTH
# 28     29  SOC - B1  RA2011051010011            NITISH KUMAR VASHISHT
# 29     30  SOC - B1  RA2011026010117                    RAGHAV KAPOOR
# 30     31  SOC - B1  RA2011026010001                HARSHIL CHOUDHARY
# 31     32  SOC - B1  RA2011033010047                  GAYATRI MALLADI
# 32     33  SOC - B1  RA2011026010203               BARUNI VIVEK MOGHE
# 33     34  SOC - B1  RA2011031010053                      ARSH BHATIA
# 34     35  SOC - B1  RA2011003011213                    ANSHDHA SINGH
#
#                         Dep  Spl.               email id  Venue  \
# 0                       CSE   BDA   sp8802@srmist.edu.in  TP405
# 1                       CSE   CSE   as0449@srmist.edu.in  TP405
# 2                       CSE   CSE   ab5589@srmist.edu.in  TP405
# 3                       CSE   CSE   pg3834@srmist.edu.in  TP405
# 4                       CSE    CS   st8861@srmist.edu.in  TP405
# 5                       CSE   CSE   ks4237@srmist.edu.in  TP405
# 6                       CSE   CSE  as2209@srmist.edu.in   TP405
# 7                       CSE   BDA   pm3294@srmist.edu.in  TP405
# 8                       CSE   CSE  ss9710@srmist.edu.in   TP405
# 9                       CSE   BDA   dl4267@srmist.edu.in  TP405
# 10  Artificial Intelligence    AI   al2070@srmist.edu.in  TP405
# 11                      CSE    CS   ts3002@srmist.edu.in  TP405
# 12                      CSE   CSE   sg1691@srmist.edu.in  TP405
# 13                      CSE   CSE   ts5975@srmist.edu.in  TP405
# 14                      CSE  AIML   vb9359@srmist.edu.in  TP405
# 15                      CSE  AIML   aj6905@srmist.edu.in  TP405
# 16                      CSE    CC   ad9382@srmist.edu.in  TP405
# 17                      CSE    CS  mm4210@srmist.edu.in   TP405
# 18                      CSE    CC   kq3419@srmist.edu.in  TP405
# 19                      CSE   BCT   mv5434@srmist.edu.in  TP405
# 20                      CSE  AIML   as3246@srmist.edu.in  TP405
# 21                      CSE  AIML   mn4883@srmist.edu.in  TP405
# 22                      CSE   CSE   bd6905@srmist.edu.in  TP405
# 23                      CSE    CC   as8662@srmist.edu.in  TP405
# 24                      CSE    IT   as0262@srmist.edu.in  TP405
# 25                      CSE    SW   sj8116@srmist.edu.in  TP405
# 26                      CSE    IT  ng2835@srmist.edu.in   TP405
# 27                      CSE    CS   pr8259@srmist.edu.in  TP405
# 28                      CSE    GT   nv7336@srmist.edu.in  TP405
# 29                      CSE  AIML   rk6073@srmist.edu.in  TP405
# 30                      CSE  AIML   hc4653@srmist.edu.in  TP405
# 31                      CSE    SW   gm7551@srmist.edu.in  TP405
# 32                      CSE  AIML   bm6641@srmist.edu.in  TP405
# 33                      CSE    IT  ab4662@srmist.edu.in   TP405
# 34                      CSE   CSE   as6316@srmist.edu.in  TP405
#
#    09/06/2023 - Att  Remarks
# 0                 A      NaN
# 1                 A      NaN
# 2                 A      NaN
# 3                 A      NaN
# 4                 A      NaN
# 5                 A      NaN
# 6                 P      NaN
# 7                 A      NaN
# 8                 P      NaN
# 9                 A      NaN
# 10                A      NaN
# 11                P      NaN
# 12                A      NaN
# 13                A      NaN
# 14                A      NaN
# 15                P      NaN
# 16                A      NaN
# 17                P      NaN
# 18                A      NaN
# 19                P      NaN
# 20                A      NaN
# 21                P      NaN
# 22                A      NaN
# 23                A      NaN
# 24                A      NaN
# 25                A      NaN
# 26                A      NaN
# 27                A      NaN
# 28                P      NaN
# 29                A      NaN
# 30                A      NaN
# 31                A      NaN
# 32                P      NaN
# 33                A      NaN
# 34                A      NaN

# %%
nothing = pd.read_csv('nothing.csv')

# %%
nothing
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21410    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21414    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# 1              0  Business Data Collection - BDC
# 2              0  Business Data Collection - BDC
# 3              0  Business Data Collection - BDC
# 4              0  Business Data Collection - BDC
# ...          ...                             ...
# 21410          0  Business Data Collection - BDC
# 21411          0  Business Data Collection - BDC
# 21412          0  Business Data Collection - BDC
# 21413          0  Business Data Collection - BDC
# 21414          0  Business Data Collection - BDC
#
#                                               Group  \
# 0                   Industry by employment variable
# 1                   Industry by employment variable
# 2                   Industry by employment variable
# 3                   Industry by employment variable
# 4                   Industry by employment variable
# ...                                             ...
# 21410  Territorial authority by employment variable
# 21411  Territorial authority by employment variable
# 21412  Territorial authority by employment variable
# 21413  Territorial authority by employment variable
# 21414  Territorial authority by employment variable
#
#                                Series_title_1  \
# 0                                 Filled jobs
# 1                                 Filled jobs
# 2                                 Filled jobs
# 3                                 Filled jobs
# 4                                 Filled jobs
# ...                                       ...
# 21410  Filled jobs (workplace location based)
# 21411  Filled jobs (workplace location based)
# 21412  Filled jobs (workplace location based)
# 21413  Filled jobs (workplace location based)
# 21414  Filled jobs (workplace location based)
#
#                            Series_title_2 Series_title_3  Series_title_4  \
# 0       Agriculture, Forestry and Fishing         Actual             NaN
# 1       Agriculture, Forestry and Fishing         Actual             NaN
# 2       Agriculture, Forestry and Fishing         Actual             NaN
# 3       Agriculture, Forestry and Fishing         Actual             NaN
# 4       Agriculture, Forestry and Fishing         Actual             NaN
# ...                                   ...            ...             ...
# 21410  Area Outside Territorial Authority         Actual             NaN
# 21411  Area Outside Territorial Authority         Actual             NaN
# 21412  Area Outside Territorial Authority         Actual             NaN
# 21413  Area Outside Territorial Authority         Actual             NaN
# 21414  Area Outside Territorial Authority         Actual             NaN
#
#        Series_title_5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 21410             NaN
# 21411             NaN
# 21412             NaN
# 21413             NaN
# 21414             NaN
#
# [21415 rows x 14 columns]

# %%
f.head(67)
# Out:
#       Name  Places Packages
# 0   Hardik  Canada       1B
# 1  Janenie  Canada       5B
# 2    Manas  Russia       1M
# 3   Aayush     USA     0.5M

# %%
nothing.head(75)
# Out:
#    Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0       BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1       BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2       BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3       BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4       BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# ..              ...      ...         ...        ...    ...     ...        ...
# 70      BDCQ.SEA1AS  2016.12     92197.0        NaN      R  Number          0
# 71      BDCQ.SEA1AS  2017.03     92629.0        NaN      R  Number          0
# 72      BDCQ.SEA1AS  2017.06     94298.0        NaN      R  Number          0
# 73      BDCQ.SEA1AS  2017.09     94282.0        NaN      R  Number          0
# 74      BDCQ.SEA1AS  2017.12     94261.0        NaN      R  Number          0
#
#                            Subject                            Group  \
# 0   Business Data Collection - BDC  Industry by employment variable
# 1   Business Data Collection - BDC  Industry by employment variable
# 2   Business Data Collection - BDC  Industry by employment variable
# 3   Business Data Collection - BDC  Industry by employment variable
# 4   Business Data Collection - BDC  Industry by employment variable
# ..                             ...                              ...
# 70  Business Data Collection - BDC  Industry by employment variable
# 71  Business Data Collection - BDC  Industry by employment variable
# 72  Business Data Collection - BDC  Industry by employment variable
# 73  Business Data Collection - BDC  Industry by employment variable
# 74  Business Data Collection - BDC  Industry by employment variable
#
#    Series_title_1                     Series_title_2       Series_title_3  \
# 0     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 1     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 2     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 3     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 4     Filled jobs  Agriculture, Forestry and Fishing               Actual
# ..            ...                                ...                  ...
# 70    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 71    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 72    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 73    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 74    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
#
#     Series_title_4  Series_title_5
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# ..             ...             ...
# 70             NaN             NaN
# 71             NaN             NaN
# 72             NaN             NaN
# 73             NaN             NaN
# 74             NaN             NaN
#
# [75 rows x 14 columns]

# %%
f.place
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/p2/6mgfcw956d17xkqh172sdjk40000gn/T/ipykernel_11083/2524521819.py in ?()
# ----> 1 f.place
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'place'

# %%
f
# Out:
#       Name  Places Packages
# 0   Hardik  Canada       1B
# 1  Janenie  Canada       5B
# 2    Manas  Russia       1M
# 3   Aayush     USA     0.5M

# %%
f.Places
# Out:
# 0    Canada
# 1    Canada
# 2    Russia
# 3       USA
# Name: Places, dtype: object

# %%
f.index=['I','II','III','IV']

# %%
f
# Out:
#         Name  Places Packages
# I     Hardik  Canada       1B
# II   Janenie  Canada       5B
# III    Manas  Russia       1M
# IV    Aayush     USA     0.5M

# %%
type(f)
# Out:
# pandas.core.frame.DataFrame

# %%
type(f.Name)
# Out:
# pandas.core.series.Series

# %%
newdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 newdf
#
# NameError: name 'newdf' is not defined
