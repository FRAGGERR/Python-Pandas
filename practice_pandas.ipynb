# %%
import pandas as pd

# %%
import numpy as np

# %%
dict= {
    "Name" : ['Hardik', 'Janenie', 'Manas','Aayush'],
    "Places" : ['Canada', 'Canada', 'Russia', 'USA'],
    "Packages" : ['1B','5B','1M','0.5M']
}

# %%
f=pd.DataFrame(dict)

# %%
f
# Out:
#       Name  Places Packages
# 0   Hardik  Canada       1B
# 1  Janenie  Canada       5B
# 2    Manas  Russia       1M
# 3   Aayush     USA     0.5M

# %%
f.to_csv("hardik.csv")

# %%
f.to_csv("hardik_index_false.csv", index = False)

# %%
f.head(2)
# Out:
#       Name  Places Packages
# 0   Hardik  Canada       1B
# 1  Janenie  Canada       5B

# %%
f.tail(1)
# Out:
#      Name Places Packages
# 3  Aayush    USA     0.5M

# %%
f.describe()
# Out:
#           Name  Places Packages
# count        4       4        4
# unique       4       3        4
# top     Hardik  Canada       1B
# freq         1       2        1

# %%
hardik = pd.read_csv('hardik.csv')

# %%
hardik
# Out:
#    Unnamed: 0     Name  Places Packages
# 0           0   Hardik  Canada       1B
# 1           1  Janenie  Canada       5B
# 2           2    Manas  Russia       1M
# 3           3   Aayush     USA     0.5M

# %%
nothing = pd.read_csv('nothing.csv')

# %%
nothing
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21410    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21414    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# 1              0  Business Data Collection - BDC
# 2              0  Business Data Collection - BDC
# 3              0  Business Data Collection - BDC
# 4              0  Business Data Collection - BDC
# ...          ...                             ...
# 21410          0  Business Data Collection - BDC
# 21411          0  Business Data Collection - BDC
# 21412          0  Business Data Collection - BDC
# 21413          0  Business Data Collection - BDC
# 21414          0  Business Data Collection - BDC
#
#                                               Group  \
# 0                   Industry by employment variable
# 1                   Industry by employment variable
# 2                   Industry by employment variable
# 3                   Industry by employment variable
# 4                   Industry by employment variable
# ...                                             ...
# 21410  Territorial authority by employment variable
# 21411  Territorial authority by employment variable
# 21412  Territorial authority by employment variable
# 21413  Territorial authority by employment variable
# 21414  Territorial authority by employment variable
#
#                                Series_title_1  \
# 0                                 Filled jobs
# 1                                 Filled jobs
# 2                                 Filled jobs
# 3                                 Filled jobs
# 4                                 Filled jobs
# ...                                       ...
# 21410  Filled jobs (workplace location based)
# 21411  Filled jobs (workplace location based)
# 21412  Filled jobs (workplace location based)
# 21413  Filled jobs (workplace location based)
# 21414  Filled jobs (workplace location based)
#
#                            Series_title_2 Series_title_3  Series_title_4  \
# 0       Agriculture, Forestry and Fishing         Actual             NaN
# 1       Agriculture, Forestry and Fishing         Actual             NaN
# 2       Agriculture, Forestry and Fishing         Actual             NaN
# 3       Agriculture, Forestry and Fishing         Actual             NaN
# 4       Agriculture, Forestry and Fishing         Actual             NaN
# ...                                   ...            ...             ...
# 21410  Area Outside Territorial Authority         Actual             NaN
# 21411  Area Outside Territorial Authority         Actual             NaN
# 21412  Area Outside Territorial Authority         Actual             NaN
# 21413  Area Outside Territorial Authority         Actual             NaN
# 21414  Area Outside Territorial Authority         Actual             NaN
#
#        Series_title_5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 21410             NaN
# 21411             NaN
# 21412             NaN
# 21413             NaN
# 21414             NaN
#
# [21415 rows x 14 columns]

# %%
f.head(67)
# Out:
#       Name  Places Packages
# 0   Hardik  Canada       1B
# 1  Janenie  Canada       5B
# 2    Manas  Russia       1M
# 3   Aayush     USA     0.5M

# %%
nothing.head(75)
# Out:
#    Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0       BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1       BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2       BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3       BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4       BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# ..              ...      ...         ...        ...    ...     ...        ...
# 70      BDCQ.SEA1AS  2016.12     92197.0        NaN      R  Number          0
# 71      BDCQ.SEA1AS  2017.03     92629.0        NaN      R  Number          0
# 72      BDCQ.SEA1AS  2017.06     94298.0        NaN      R  Number          0
# 73      BDCQ.SEA1AS  2017.09     94282.0        NaN      R  Number          0
# 74      BDCQ.SEA1AS  2017.12     94261.0        NaN      R  Number          0
#
#                            Subject                            Group  \
# 0   Business Data Collection - BDC  Industry by employment variable
# 1   Business Data Collection - BDC  Industry by employment variable
# 2   Business Data Collection - BDC  Industry by employment variable
# 3   Business Data Collection - BDC  Industry by employment variable
# 4   Business Data Collection - BDC  Industry by employment variable
# ..                             ...                              ...
# 70  Business Data Collection - BDC  Industry by employment variable
# 71  Business Data Collection - BDC  Industry by employment variable
# 72  Business Data Collection - BDC  Industry by employment variable
# 73  Business Data Collection - BDC  Industry by employment variable
# 74  Business Data Collection - BDC  Industry by employment variable
#
#    Series_title_1                     Series_title_2       Series_title_3  \
# 0     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 1     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 2     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 3     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 4     Filled jobs  Agriculture, Forestry and Fishing               Actual
# ..            ...                                ...                  ...
# 70    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 71    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 72    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 73    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 74    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
#
#     Series_title_4  Series_title_5
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# ..             ...             ...
# 70             NaN             NaN
# 71             NaN             NaN
# 72             NaN             NaN
# 73             NaN             NaN
# 74             NaN             NaN
#
# [75 rows x 14 columns]

# %%
f.place()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/p2/6mgfcw956d17xkqh172sdjk40000gn/T/ipykernel_75670/1326982629.py in ?()
# ----> 1 f.place()
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'place'

# %%
f
# Out:
#       Name  Places Packages
# 0   Hardik  Canada       1B
# 1  Janenie  Canada       5B
# 2    Manas  Russia       1M
# 3   Aayush     USA     0.5M

# %%
f.Places
# Out:
# 0    Canada
# 1    Canada
# 2    Russia
# 3       USA
# Name: Places, dtype: object

# %%
f.index=['I','II','III','IV']

# %%
f
# Out:
#         Name  Places Packages
# I     Hardik  Canada       1B
# II   Janenie  Canada       5B
# III    Manas  Russia       1M
# IV    Aayush     USA     0.5M

# %%
type(f)
# Out:
# pandas.core.frame.DataFrame

# %%
type(f.Name)
# Out:
# pandas.core.series.Series

# %%
newdf = pd. DataFrame(np.random. rand (334,5), index=np.arange (334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.706400  0.441180  0.322115  0.106793  0.136631
# 1    0.481765  0.147244  0.564089  0.187056  0.921268
# 2    0.373705  0.600414  0.813719  0.242490  0.784919
# 3    0.504934  0.334482  0.981974  0.738312  0.408226
# 4    0.093721  0.629799  0.628900  0.762944  0.295391
# ..        ...       ...       ...       ...       ...
# 329  0.043185  0.280277  0.713696  0.551920  0.708695
# 330  0.607106  0.619730  0.836259  0.613988  0.147089
# 331  0.121363  0.550828  0.251081  0.386838  0.601010
# 332  0.990659  0.081066  0.834171  0.987780  0.676309
# 333  0.855664  0.617901  0.519577  0.672384  0.683096
#
# [334 rows x 5 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.506376    0.523857    0.499692    0.520403    0.487109
# std      0.279956    0.276764    0.285682    0.275885    0.283883
# min      0.002005    0.003817    0.000686    0.005188    0.004614
# 25%      0.287828    0.298484    0.259479    0.298349    0.238786
# 50%      0.498005    0.556352    0.507763    0.549086    0.478519
# 75%      0.730519    0.747593    0.727298    0.762350    0.728732
# max      0.998344    0.994532    0.995294    0.999347    0.995370

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[3][1]='hardik'

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.706400  0.441180  0.322115  0.106793  0.136631
# 1  0.481765  0.147244  0.564089    hardik  0.921268
# 2  0.373705  0.600414  0.813719   0.24249  0.784919
# 3  0.504934  0.334482  0.981974  0.738312  0.408226
# 4  0.093721  0.629799  0.628900  0.762944  0.295391

# %%
newdf.to_csv("newdf.csv")

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.T #this is use to transpose the dataframe
# Out:
#         0         1         2         3         4         5         6    \
# 0    0.7064  0.481765  0.373705  0.504934  0.093721   0.74524  0.349098
# 1   0.44118  0.147244  0.600414  0.334482  0.629799  0.572026  0.444208
# 2  0.322115  0.564089  0.813719  0.981974    0.6289  0.118528  0.424091
# 3  0.106793    hardik   0.24249  0.738312  0.762944  0.159563  0.606863
# 4  0.136631  0.921268  0.784919  0.408226  0.295391   0.77716  0.004614
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.328822  0.421843  0.818639  ...  0.134315  0.050932  0.497793  0.390776
# 1  0.153263  0.576487   0.18197  ...  0.901793  0.432083  0.290332  0.185157
# 2  0.313409  0.757075  0.692265  ...  0.688793  0.089815  0.366676  0.448834
# 3  0.671975  0.308592  0.881662  ...  0.847665  0.720677  0.158192  0.328989
# 4  0.513754  0.272264  0.284918  ...  0.418878  0.489929  0.005496  0.749705
#
#         328       329       330       331       332       333
# 0  0.508732  0.043185  0.607106  0.121363  0.990659  0.855664
# 1  0.881022  0.280277   0.61973  0.550828  0.081066  0.617901
# 2  0.913922  0.713696  0.836259  0.251081  0.834171  0.519577
# 3   0.45523   0.55192  0.613988  0.386838   0.98778  0.672384
# 4  0.563157  0.708695  0.147089   0.60101  0.676309  0.683096
#
# [5 rows x 334 columns]

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.706400  0.441180  0.322115  0.106793  0.136631
# 1    0.481765  0.147244  0.564089    hardik  0.921268
# 2    0.373705  0.600414  0.813719   0.24249  0.784919
# 3    0.504934  0.334482  0.981974  0.738312  0.408226
# 4    0.093721  0.629799  0.628900  0.762944  0.295391
# ..        ...       ...       ...       ...       ...
# 329  0.043185  0.280277  0.713696   0.55192  0.708695
# 330  0.607106  0.619730  0.836259  0.613988  0.147089
# 331  0.121363  0.550828  0.251081  0.386838  0.601010
# 332  0.990659  0.081066  0.834171   0.98778  0.676309
# 333  0.855664  0.617901  0.519577  0.672384  0.683096
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.706400  0.441180  0.322115  0.106793  0.136631
# 1  0.481765  0.147244  0.564089    hardik  0.921268
# 2  0.373705  0.600414  0.813719   0.24249  0.784919
# 3  0.504934  0.334482  0.981974  0.738312  0.408226
# 4  0.093721  0.629799  0.628900  0.762944  0.295391

# %%
newdf. drop (4, axis=1)#axis = 0 that means row, axis = 1 means column
# Out:
#             0         1         2         3
# 0    0.706400  0.441180  0.322115  0.106793
# 1    0.481765  0.147244  0.564089    hardik
# 2    0.373705  0.600414  0.813719   0.24249
# 3    0.504934  0.334482  0.981974  0.738312
# 4    0.093721  0.629799  0.628900  0.762944
# ..        ...       ...       ...       ...
# 329  0.043185  0.280277  0.713696   0.55192
# 330  0.607106  0.619730  0.836259  0.613988
# 331  0.121363  0.550828  0.251081  0.386838
# 332  0.990659  0.081066  0.834171   0.98778
# 333  0.855664  0.617901  0.519577  0.672384
#
# [334 rows x 4 columns]

# %%
dict1 = {
    "Bank" : ["ICICI", "SBI", "AXIS", "CITY UNION BANK", "HDFC"],
}

# %%
import pandas as pd
h= pd.DataFrame(dict1)

# %%
h
# Out:
#               Bank
# 0            ICICI
# 1              SBI
# 2             AXIS
# 3  CITY UNION BANK
# 4             HDFC

# %%
print("hello")
# Out:
# hello

# %%
hello = ("This is Deepshikha Chhipa, Sister of Mr.Hardik Chhipa")
print(hello)
# Out:
# This is Deepshikha Chhipa, Sister of Mr.Hardik Chhipa

# %%
h
# Out:
#               Bank
# 0            ICICI
# 1              SBI
# 2             AXIS
# 3  CITY UNION BANK
# 4             HDFC

# %%
h
# Out:
#               Bank
# 0            ICICI
# 1              SBI
# 2             AXIS
# 3  CITY UNION BANK
# 4             HDFC

# %%
import os
import pandas as pd

current_dir = os.getcwd()


filename = 'h.csv'


file_path = os.path.join(current_dir, h)

# Read the CSV file using pandas
df = pd.read_csv(h)

# Perform operations on the dataframe as needed
# ...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 10
#       4 current_dir = os.getcwd()
#       7 filename = 'h.csv'
# ---> 10 file_path = os.path.join(current_dir, h)
#      12 # Read the CSV file using pandas
#      13 df = pd.read_csv(h)
#
# File <frozen posixpath>:90, in join(a, *p)
#
# File <frozen genericpath>:152, in _check_arg_types(funcname, *args)
#
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'DataFrame'

# %%
h
# Out:
#               Bank
# 0            ICICI
# 1              SBI
# 2             AXIS
# 3  CITY UNION BANK
# 4             HDFC

# %%
nothing  =  pd.read_csv("nothing.csv")

# %%
nothing
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21410    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21414    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# 1              0  Business Data Collection - BDC
# 2              0  Business Data Collection - BDC
# 3              0  Business Data Collection - BDC
# 4              0  Business Data Collection - BDC
# ...          ...                             ...
# 21410          0  Business Data Collection - BDC
# 21411          0  Business Data Collection - BDC
# 21412          0  Business Data Collection - BDC
# 21413          0  Business Data Collection - BDC
# 21414          0  Business Data Collection - BDC
#
#                                               Group  \
# 0                   Industry by employment variable
# 1                   Industry by employment variable
# 2                   Industry by employment variable
# 3                   Industry by employment variable
# 4                   Industry by employment variable
# ...                                             ...
# 21410  Territorial authority by employment variable
# 21411  Territorial authority by employment variable
# 21412  Territorial authority by employment variable
# 21413  Territorial authority by employment variable
# 21414  Territorial authority by employment variable
#
#                                Series_title_1  \
# 0                                 Filled jobs
# 1                                 Filled jobs
# 2                                 Filled jobs
# 3                                 Filled jobs
# 4                                 Filled jobs
# ...                                       ...
# 21410  Filled jobs (workplace location based)
# 21411  Filled jobs (workplace location based)
# 21412  Filled jobs (workplace location based)
# 21413  Filled jobs (workplace location based)
# 21414  Filled jobs (workplace location based)
#
#                            Series_title_2 Series_title_3  Series_title_4  \
# 0       Agriculture, Forestry and Fishing         Actual             NaN
# 1       Agriculture, Forestry and Fishing         Actual             NaN
# 2       Agriculture, Forestry and Fishing         Actual             NaN
# 3       Agriculture, Forestry and Fishing         Actual             NaN
# 4       Agriculture, Forestry and Fishing         Actual             NaN
# ...                                   ...            ...             ...
# 21410  Area Outside Territorial Authority         Actual             NaN
# 21411  Area Outside Territorial Authority         Actual             NaN
# 21412  Area Outside Territorial Authority         Actual             NaN
# 21413  Area Outside Territorial Authority         Actual             NaN
# 21414  Area Outside Territorial Authority         Actual             NaN
#
#        Series_title_5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 21410             NaN
# 21411             NaN
# 21412             NaN
# 21413             NaN
# 21414             NaN
#
# [21415 rows x 14 columns]

# %%
nothing.head(80)
# Out:
#    Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0       BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1       BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2       BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3       BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4       BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# ..              ...      ...         ...        ...    ...     ...        ...
# 75      BDCQ.SEA1AS  2018.03     94888.0        NaN      R  Number          0
# 76      BDCQ.SEA1AS  2018.06     94609.0        NaN      R  Number          0
# 77      BDCQ.SEA1AS  2018.09     94003.0        NaN      R  Number          0
# 78      BDCQ.SEA1AS  2018.12     95249.0        NaN      R  Number          0
# 79      BDCQ.SEA1AS  2019.03     96134.0        NaN      R  Number          0
#
#                            Subject                            Group  \
# 0   Business Data Collection - BDC  Industry by employment variable
# 1   Business Data Collection - BDC  Industry by employment variable
# 2   Business Data Collection - BDC  Industry by employment variable
# 3   Business Data Collection - BDC  Industry by employment variable
# 4   Business Data Collection - BDC  Industry by employment variable
# ..                             ...                              ...
# 75  Business Data Collection - BDC  Industry by employment variable
# 76  Business Data Collection - BDC  Industry by employment variable
# 77  Business Data Collection - BDC  Industry by employment variable
# 78  Business Data Collection - BDC  Industry by employment variable
# 79  Business Data Collection - BDC  Industry by employment variable
#
#    Series_title_1                     Series_title_2       Series_title_3  \
# 0     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 1     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 2     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 3     Filled jobs  Agriculture, Forestry and Fishing               Actual
# 4     Filled jobs  Agriculture, Forestry and Fishing               Actual
# ..            ...                                ...                  ...
# 75    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 76    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 77    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 78    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
# 79    Filled jobs  Agriculture, Forestry and Fishing  Seasonally adjusted
#
#     Series_title_4  Series_title_5
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# ..             ...             ...
# 75             NaN             NaN
# 76             NaN             NaN
# 77             NaN             NaN
# 78             NaN             NaN
# 79             NaN             NaN
#
# [80 rows x 14 columns]

# %%
nothing
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21410    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21414    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# 1              0  Business Data Collection - BDC
# 2              0  Business Data Collection - BDC
# 3              0  Business Data Collection - BDC
# 4              0  Business Data Collection - BDC
# ...          ...                             ...
# 21410          0  Business Data Collection - BDC
# 21411          0  Business Data Collection - BDC
# 21412          0  Business Data Collection - BDC
# 21413          0  Business Data Collection - BDC
# 21414          0  Business Data Collection - BDC
#
#                                               Group  \
# 0                   Industry by employment variable
# 1                   Industry by employment variable
# 2                   Industry by employment variable
# 3                   Industry by employment variable
# 4                   Industry by employment variable
# ...                                             ...
# 21410  Territorial authority by employment variable
# 21411  Territorial authority by employment variable
# 21412  Territorial authority by employment variable
# 21413  Territorial authority by employment variable
# 21414  Territorial authority by employment variable
#
#                                Series_title_1  \
# 0                                 Filled jobs
# 1                                 Filled jobs
# 2                                 Filled jobs
# 3                                 Filled jobs
# 4                                 Filled jobs
# ...                                       ...
# 21410  Filled jobs (workplace location based)
# 21411  Filled jobs (workplace location based)
# 21412  Filled jobs (workplace location based)
# 21413  Filled jobs (workplace location based)
# 21414  Filled jobs (workplace location based)
#
#                            Series_title_2 Series_title_3  Series_title_4  \
# 0       Agriculture, Forestry and Fishing         Actual             NaN
# 1       Agriculture, Forestry and Fishing         Actual             NaN
# 2       Agriculture, Forestry and Fishing         Actual             NaN
# 3       Agriculture, Forestry and Fishing         Actual             NaN
# 4       Agriculture, Forestry and Fishing         Actual             NaN
# ...                                   ...            ...             ...
# 21410  Area Outside Territorial Authority         Actual             NaN
# 21411  Area Outside Territorial Authority         Actual             NaN
# 21412  Area Outside Territorial Authority         Actual             NaN
# 21413  Area Outside Territorial Authority         Actual             NaN
# 21414  Area Outside Territorial Authority         Actual             NaN
#
#        Series_title_5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 21410             NaN
# 21411             NaN
# 21412             NaN
# 21413             NaN
# 21414             NaN
#
# [21415 rows x 14 columns]

# %%
f
# Out:
#         Name  Places Packages
# I     Hardik  Canada       1B
# II   Janenie  Canada       5B
# III    Manas  Russia       1M
# IV    Aayush     USA     0.5M
